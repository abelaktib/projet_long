# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
## path file result
str_filename="data/historybigdata.csv"

# %% [markdown]
# # Open the file and check header

# %%
fh=open(str_filename)
csv_reader=csv.reader(fh)
csv_header=next(csv_reader)
csv_header
# Out:
# ['EPOCHS',
#  'BATCH',
#  'ACCURACY',
#  'VAL_ACCURACY',
#  'LOSS',
#  'VAL_LOSS',
#  'ROC',
#  'PR',
#  'VAL_ROC',
#  'VAL_PR',
#  'PRECISION',
#  'RECALL',
#  'VAL_PRECISION',
#  'VAL_RECALL',
#  'BIN_ACC',
#  'VAL_BIN_ACC',
#  'LR',
#  'TRUE_POSITIVES',
#  'TRUE_NEGATIVES',
#  'FALSE_POSITIVES',
#  'FALSE_NEGATIVES',
#  'VAL_TRUE_POSITIVES',
#  'VAL_TRUE_NEGATIVES',
#  'VAL_FALSE_POSITIVES',
#  'VAL_FALSE_NEGATIVES']

# %% [markdown]
# # Visualize the file

# %%
df_sig=pd.read_csv(str_filename,names=csv_header,header=0)
df_sig
# Out:
#     EPOCHS  BATCH  ACCURACY  VAL_ACCURACY      LOSS  VAL_LOSS       ROC  \
# 0        0     64  0.996233      0.914472  0.000089  0.000679  0.930156
# 1        1     64  0.996865      0.914472  0.000027  0.000676  0.930871
# 2        2     64  0.996865      0.914472  0.000027  0.000675  0.930871
# 3        3     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 4        4     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 5        5     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 6        6     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 7        7     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 8        8     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 9        9     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 10      10     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 11      11     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 12      12     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 13      13     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 14      14     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 15      15     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 16      16     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 17      17     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 18      18     64  0.996865      0.914472  0.000027  0.000673  0.930871
# 19      19     64  0.996865      0.914472  0.000027  0.000673  0.930871
#
#           PR   VAL_ROC    VAL_PR  ...  VAL_BIN_ACC            LR  \
# 0   0.911594  0.913395  0.891423  ...     0.913395  1.000000e-04
# 1   0.912591  0.913395  0.891423  ...     0.913395  1.000000e-04
# 2   0.912591  0.913395  0.891423  ...     0.913395  1.000000e-04
# 3   0.912591  0.913395  0.891423  ...     0.913395  2.000000e-05
# 4   0.912591  0.913395  0.891423  ...     0.913395  2.000000e-05
# 5   0.912591  0.913395  0.891423  ...     0.913395  4.000000e-06
# 6   0.912591  0.913395  0.891423  ...     0.913395  4.000000e-06
# 7   0.912591  0.913395  0.891423  ...     0.913395  8.000000e-07
# 8   0.912591  0.913395  0.891423  ...     0.913395  8.000000e-07
# 9   0.912591  0.913395  0.891423  ...     0.913395  1.600000e-07
# 10  0.912591  0.913395  0.891423  ...     0.913395  1.600000e-07
# 11  0.912591  0.913395  0.891423  ...     0.913395  3.200000e-08
# 12  0.912591  0.913395  0.891423  ...     0.913395  3.200000e-08
# 13  0.912591  0.913395  0.891423  ...     0.913395  6.400000e-09
# 14  0.912591  0.913395  0.891423  ...     0.913395  6.400000e-09
# 15  0.912591  0.913395  0.891423  ...     0.913395  1.280000e-09
# 16  0.912591  0.913395  0.891423  ...     0.913395  1.280000e-09
# 17  0.912591  0.913395  0.891423  ...     0.913395  2.560000e-10
# 18  0.912591  0.913395  0.891423  ...     0.913395  2.560000e-10
# 19  0.912591  0.913395  0.891423  ...     0.913395  5.120000e-11
#
#     TRUE_POSITIVES  TRUE_NEGATIVES  FALSE_POSITIVES  FALSE_NEGATIVES  \
# 0        3132541.0       3132541.0         234544.0         234544.0
# 1        3134321.0       3134321.0         232764.0         232764.0
# 2        3134321.0       3134321.0         232764.0         232764.0
# 3        3134321.0       3134321.0         232764.0         232764.0
# 4        3134321.0       3134321.0         232764.0         232764.0
# 5        3134321.0       3134321.0         232764.0         232764.0
# 6        3134321.0       3134321.0         232764.0         232764.0
# 7        3134321.0       3134321.0         232764.0         232764.0
# 8        3134321.0       3134321.0         232764.0         232764.0
# 9        3134321.0       3134321.0         232764.0         232764.0
# 10       3134321.0       3134321.0         232764.0         232764.0
# 11       3134321.0       3134321.0         232764.0         232764.0
# 12       3134321.0       3134321.0         232764.0         232764.0
# 13       3134321.0       3134321.0         232764.0         232764.0
# 14       3134321.0       3134321.0         232764.0         232764.0
# 15       3134321.0       3134321.0         232764.0         232764.0
# 16       3134321.0       3134321.0         232764.0         232764.0
# 17       3134321.0       3134321.0         232764.0         232764.0
# 18       3134321.0       3134321.0         232764.0         232764.0
# 19       3134321.0       3134321.0         232764.0         232764.0
#
#     VAL_TRUE_POSITIVES  VAL_TRUE_NEGATIVES  VAL_FALSE_POSITIVES  \
# 0             242722.0            242722.0              23014.0
# 1             242722.0            242722.0              23014.0
# 2             242722.0            242722.0              23014.0
# 3             242722.0            242722.0              23014.0
# 4             242722.0            242722.0              23014.0
# 5             242722.0            242722.0              23014.0
# 6             242722.0            242722.0              23014.0
# 7             242722.0            242722.0              23014.0
# 8             242722.0            242722.0              23014.0
# 9             242722.0            242722.0              23014.0
# 10            242722.0            242722.0              23014.0
# 11            242722.0            242722.0              23014.0
# 12            242722.0            242722.0              23014.0
# 13            242722.0            242722.0              23014.0
# 14            242722.0            242722.0              23014.0
# 15            242722.0            242722.0              23014.0
# 16            242722.0            242722.0              23014.0
# 17            242722.0            242722.0              23014.0
# 18            242722.0            242722.0              23014.0
# 19            242722.0            242722.0              23014.0
#
#     VAL_FALSE_NEGATIVES
# 0               23014.0
# 1               23014.0
# 2               23014.0
# 3               23014.0
# 4               23014.0
# 5               23014.0
# 6               23014.0
# 7               23014.0
# 8               23014.0
# 9               23014.0
# 10              23014.0
# 11              23014.0
# 12              23014.0
# 13              23014.0
# 14              23014.0
# 15              23014.0
# 16              23014.0
# 17              23014.0
# 18              23014.0
# 19              23014.0
#
# [20 rows x 25 columns]

# %% [markdown]
# # LOSS & ACCURACY

# %%
plt.plot(df_sig['ACCURACY'])
plt.plot(df_sig['VAL_ACCURACY'])
plt.plot(df_sig['LOSS'])
plt.plot(df_sig['VAL_LOSS'])
plt.legend(['ACCURACY','VAL_ACCURACY','LOSS','VAL_LOSS'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # LOSS ONLY

# %%
plt.plot(df_sig['LOSS'])
plt.plot(df_sig['VAL_LOSS'])
plt.legend(['Train','VALIDATION'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # Others metrics

# %%
plt.plot(df_sig['ROC'])
plt.plot(df_sig['VAL_ROC'])
plt.plot(df_sig['PR'])
plt.plot(df_sig['VAL_PR'])


plt.plot(df_sig['PRECISION'])
plt.plot(df_sig['VAL_PRECISION'])
plt.plot(df_sig['RECALL'])
plt.plot(df_sig['VAL_RECALL'])
plt.plot(df_sig['BIN_ACC'])
plt.plot(df_sig['VAL_BIN_ACC'])


plt.legend(['ROC','VAL_ROC','PR','VAL_PR','PRECISION','VAL_PRECISION','RECALL','VAL_RECALL','BIN_ACC','VAL_BIN_ACC'])
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # Confusion Matrix for train set

# %%
TP= df_sig['TRUE_POSITIVES'][19]
TN= df_sig['TRUE_NEGATIVES'][19]
FP= df_sig['FALSE_POSITIVES'][19]
FN= df_sig['FALSE_NEGATIVES'][19]

# %%
cm=np.empty([2, 2])
cm[0][0] = TP
cm[1][1] = TN
cm[0][1] = FP
cm[1][0] = FN
cm
# Out:
# array([[3134321.,  232764.],
#        [ 232764., 3134321.]])

# %% [markdown]
# # Confusion Matrix for Validation set

# %%
VTP= df_sig['VAL_TRUE_POSITIVES'][19]
VTN= df_sig['VAL_TRUE_NEGATIVES'][19]
VFP= df_sig['VAL_FALSE_POSITIVES'][19]
VFN= df_sig['VAL_FALSE_NEGATIVES'][19]

# %%
vcm=np.empty([2, 2])
vcm[0][0] = VTP
vcm[1][1] = VTN
vcm[0][1] = VFP
vcm[1][0] = VFN
vcm
# Out:
# array([[242722.,  23014.],
#        [ 23014., 242722.]])
